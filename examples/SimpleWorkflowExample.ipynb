# %%
import sys
import os
sys.path.append(os.path.abspath("../src/"))
import cdsaxs

# %%
csv_path = os.path.abspath("path/to/csv/metadata/file/here")

# %%
dataset = cdsaxs.loaders.GeneralTIFFLoader(csv_path, name="Test Dataset")
dataset.update_all_metadata({'center_px': [740, 490]})  # make sure to update the beam center for all, eventually we can try automating this
# Out:
# Made dataset from C:\Users\cmw5\Documents\beamtime_data\20250310_NSLSII_SMI\data\combined_W204_F2_singleScan
# C:\Users\cmw5\Documents\github_repos\nist_cdsaxs\src\cdsaxs\loaders.py:126: UserWarning: Using default pixel size of 172
#   warnings.warn(

# %%
data = dataset.datas["W204_F2measure1_5.2m_16.1keV_num43_-17deg_bpm0.419_id857164_combined.tif"]

# %%
fig = data.plot_data()
fig

# %%
figs = dataset.plot_datas()
len(figs)

# %%
figs[10]
